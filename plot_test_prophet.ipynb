# %%
# %matplotlib inline
import pandas as pd
from fbprophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('AirPassengers.csv')

df.head(5)
# Out:
#      Month  AirPassengers
# 0  1949-01            112
# 1  1949-02            118
# 2  1949-03            132
# 3  1949-04            129
# 4  1949-05            121

# %%
df.dtypes
# Out:
# Month            object
# AirPassengers     int64
# dtype: object

# %%
df['Month'] = pd.DatetimeIndex(df['Month'])
df.dtypes
# Out:
# Month            datetime64[ns]
# AirPassengers             int64
# dtype: object

# %%
df = df.rename(columns={'Month': 'ds',
                        'AirPassengers': 'y'})

df.head(5)
# Out:
#           ds    y
# 0 1949-01-01  112
# 1 1949-02-01  118
# 2 1949-03-01  132
# 3 1949-04-01  129
# 4 1949-05-01  121

# %%
ax = df.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Monthly Number of Airline Passengers')
ax.set_xlabel('Date')

plt.show()

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width=0.95)

# %%
my_model.fit(df)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_dates = my_model.make_future_dataframe(periods=36, freq='MS')
future_dates.tail()
# Out:
#             ds
# 175 1963-08-01
# 176 1963-09-01
# 177 1963-10-01
# 178 1963-11-01
# 179 1963-12-01

# %%
forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 175 1963-08-01  649.762691  606.255222  690.536716
# 176 1963-09-01  602.208825  560.164515  648.977918
# 177 1963-10-01  566.146573  522.832019  611.801858
# 178 1963-11-01  534.150949  492.362897  576.724908
# 179 1963-12-01  563.790461  519.691182  605.078896

# %%
my_model.plot(forecast, uncertainty=True)

# %%
my_model.plot_components(forecast)
